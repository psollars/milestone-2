# %%
import pandas as pd

pd.__version__
# Out:
# '2.1.1'

# %%
SCRATCH_DIR = "/scratch/siads696f23_class_root/siads696f23_class/psollars"

# %%
bts_faa_df = pd.read_parquet(f"{SCRATCH_DIR}/bts_faa_joined.parquet")

bts_faa_df
# Out:
#           Year  Quarter  Month  DayofMonth  DayOfWeek           FlightDate  \
# 0         2015        1      1           1          4  2015-01-01 00:00:00
# 1         2015        1      1           2          5  2015-01-02 00:00:00
# 2         2015        1      1           3          6  2015-01-03 00:00:00
# 3         2015        1      1           4          7  2015-01-04 00:00:00
# 4         2015        1      1           5          1  2015-01-05 00:00:00
# ...        ...      ...    ...         ...        ...                  ...
# 52493030  2023        2      6           1          4  2023-06-01 00:00:00
# 52493031  2023        2      6           1          4  2023-06-01 00:00:00
# 52493032  2023        2      6           1          4  2023-06-01 00:00:00
# 52493033  2023        2      6           1          4  2023-06-01 00:00:00
# 52493034  2023        2      6           1          4  2023-06-01 00:00:00
#
# ...

# %%
airport_df = pd.read_csv(f"{SCRATCH_DIR}/T_MASTER_CORD.csv")

airport_df = airport_df[airport_df["AIRPORT_IS_LATEST"].eq(1)]

airport_df
# Out:
#        AIRPORT_SEQ_ID  AIRPORT_ID AIRPORT       DISPLAY_AIRPORT_NAME  \
# 0             1000101       10001     01A       Afognak Lake Airport
# 1             1000301       10003     03A    Bear Creek Mining Strip
# 2             1000401       10004     04A            Lik Mining Camp
# 3             1000501       10005     05A       Little Squaw Airport
# 4             1000601       10006     06A               Kizhuyak Bay
# ...               ...         ...     ...                        ...
# 19136         1699001       16990     1NJ           Aeroflex Andover
# 19137         1699101       16991     3NC     Hendersonville Airport
# 19138         1699201       16992     3AK  Gold Mining Landing Strip
# 19139         1699301       16993     MN8           Walker Municipal
# 19140         9999901       99999     ZZZ    Unknown Point in Alaska
#
#       DISPLAY_AIRPORT_CITY_NAME_FULL  AIRPORT_WAC_SEQ_ID2  AIRPORT_WAC  \
# ...

# %%
coords = airport_df[
    [
        "AIRPORT",
        "DISPLAY_AIRPORT_NAME",
        "DISPLAY_AIRPORT_CITY_NAME_FULL",
        "LATITUDE",
        "LONGITUDE",
    ]
]

coords
# Out:
#       AIRPORT       DISPLAY_AIRPORT_NAME DISPLAY_AIRPORT_CITY_NAME_FULL  \
# 0         01A       Afognak Lake Airport               Afognak Lake, AK
# 1         03A    Bear Creek Mining Strip           Granite Mountain, AK
# 2         04A            Lik Mining Camp                        Lik, AK
# 3         05A       Little Squaw Airport               Little Squaw, AK
# 4         06A               Kizhuyak Bay                   Kizhuyak, AK
# ...       ...                        ...                            ...
# 19136     1NJ           Aeroflex Andover                    Andover, NJ
# 19137     3NC     Hendersonville Airport             Hendersonville, NC
# 19138     3AK  Gold Mining Landing Strip                    Tintina, AK
# 19139     MN8           Walker Municipal                     Walker, MN
# 19140     ZZZ    Unknown Point in Alaska        Unknown Point in Alaska
#
#         LATITUDE   LONGITUDE
# 0      58.109444 -152.906667
# 1      65.548056 -161.071667
# ...

# %%
origin_coords = coords.add_prefix("Origin_")
bts_faa_coords_df = pd.merge(
    bts_faa_df, origin_coords, left_on="Origin", right_on="Origin_AIRPORT", how="left"
)

dest_coords = coords.add_prefix("Dest_")
bts_faa_coords_df = pd.merge(
    bts_faa_coords_df, dest_coords, left_on="Dest", right_on="Dest_AIRPORT", how="left"
)

bts_faa_coords_df = bts_faa_coords_df.drop(
    ["Origin_AIRPORT", "Dest_AIRPORT"], axis="columns"
)

# %%
bts_faa_coords_df
# Out:
#           Year  Quarter  Month  DayofMonth  DayOfWeek           FlightDate  \
# 0         2015        1      1           1          4  2015-01-01 00:00:00
# 1         2015        1      1           2          5  2015-01-02 00:00:00
# 2         2015        1      1           3          6  2015-01-03 00:00:00
# 3         2015        1      1           4          7  2015-01-04 00:00:00
# 4         2015        1      1           5          1  2015-01-05 00:00:00
# ...        ...      ...    ...         ...        ...                  ...
# 53511903  2023        2      6           1          4  2023-06-01 00:00:00
# 53511904  2023        2      6           1          4  2023-06-01 00:00:00
# 53511905  2023        2      6           1          4  2023-06-01 00:00:00
# 53511906  2023        2      6           1          4  2023-06-01 00:00:00
# 53511907  2023        2      6           1          4  2023-06-01 00:00:00
#
# ...

# %%
bts_faa_coords_df.to_parquet(f"{SCRATCH_DIR}/bts_faa_coords.parquet")
